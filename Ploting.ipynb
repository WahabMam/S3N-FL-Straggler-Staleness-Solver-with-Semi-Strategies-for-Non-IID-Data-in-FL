# %% [markdown]
# # CNN winth (0.6) Stargglers,

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
df_main_5 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_IID/0.9_5/Main_log_2025-03-26_03-01-PM.csv')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_IID/FIRST_Exception/0.9strg_10sync/MAK_log_2025-03-26_01-40-PM.csv')
# df_Mak_20 = pd.read_csv('')
df_Mak_30 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_IID/FIRST_Exception/0.9strg_30sync/MAK_log_2025-03-26_12-56-PM.csv')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
        color='blue', linestyle='--', marker='s',
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 5 Sync')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
        color='red', linestyle='--', marker='s', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.9) Stragglers IID')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
        color='blue', linestyle='--', marker='s', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')
plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
        color='red', linestyle='--', marker='s', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.9) Stragglers IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %%
import numpy as np 
print(f"Main layer 1 max: {max(df_main_1['Accuracy'])}")
# print(f"Main layer 3 Max: {max(df_main_3['Accuracy'])}")
print(f"Main layer 5 max: {max(df_main_5['Accuracy'])}")
# print(f"Make 7 Sync: {max(df_Mak_7['Accuracy'])}")
print(f"Make 10 Sync: {max(df_Mak_10['Accuracy'])}")
# print(f"Make 20 DFL: {max(df_Mak_20['Accuracy'])}")
# print(f"Make 20 DFL: {max(df_Mak_20['Accuracy'])}")
print(f"Make 30 DFL: {max(df_Mak_30['Accuracy'])}")
# Out:
# Main layer 1 max: 52.96
# Main layer 5 max: 45.75
# Make 10 Sync: 53.74
# Make 30 DFL: 53.28

# %% [markdown]
# # CNN winth (0.9) Stargglers and Non-IID(0.01) Data and Cifar10

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_Non_IID/0.9_1/Main_log_2025-03-26_03-46-PM.csv')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
# df_main_5 = pd.read_csv('')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_Non_IID/FIRST_Exception/0.9strg_10sync/MAK_log_2025-03-26_04-27-PM.csv')
# df_Mak_20 = pd.read_csv('')
# df_Mak_30 = pd.read_csv('')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
# df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
# df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
#         color='blue', linestyle='--', marker='s',
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.9) Stragglers Non-IID')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
# df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
# df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
#         color='blue', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.9) Stragglers Non-IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %%
import numpy as np 
print(f"Main layer 1 max: {max(df_main_1['Accuracy'])}")
# print(f"Main layer 3 Max: {max(df_main_3['Accuracy'])}")
print(f"Main layer 5 max: {max(df_main_5['Accuracy'])}")
# print(f"Make 7 Sync: {max(df_Mak_7['Accuracy'])}")
print(f"Make 10 Sync: {max(df_Mak_10['Accuracy'])}")
# print(f"Make 20 DFL: {max(df_Mak_20['Accuracy'])}")
# print(f"Make 20 DFL: {max(df_Mak_20['Accuracy'])}")
print(f"Make 30 DFL: {max(df_Mak_30['Accuracy'])}")
# Out:
# Main layer 1 max: 35.56
# Main layer 5 max: 45.75
# Make 10 Sync: 38.0
# Make 30 DFL: 53.28

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Data
main = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\CNN_Non_IID\\New_300\\0.9_1\\Main_log_2025-03-20_11-39-AM.csv')
mak = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_CNN_Non_IID\\New_300\\Fully\\FIRST_Exception\\0.9strg_3sync\\MAK_log_2025-03-20_11-39-AM.csv')
mak_20 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_CNN_Non_IID\\New_300\\Fully\\FIRST_Exception\\0.9strg_20sync\\MAK_log_2025-03-20_11-57-AM.csv')
mak_10 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_CNN_Non_IID\\New_300\\Fully\\FIRST_Exception\\0.9strg_10sync\\MAK_log_2025-03-20_02-11-PM.csv')


# Apply Moving Average Smoothing (window size = 5)
main['Accuracy_Smoothed'] = main['Accuracy'].rolling(window=10, min_periods=1).mean()
mak['Accuracy_Smoothed'] = mak['Accuracy'].rolling(window=10, min_periods=1).mean()
mak_20['Accuracy_Smoothed'] = mak_20['Accuracy'].rolling(window=10, min_periods=1).mean()
mak_10['Accuracy_Smoothed'] = mak_10['Accuracy'].rolling(window=10, min_periods=1).mean()

# Plot Smoothed Accuracy Curves
plt.plot(main['Round'], main['Accuracy_Smoothed'], label='SALF')
# plt.plot(mak['Round'], mak['Accuracy_Smoothed'], label='Our', color='blue')
plt.plot(mak_20['Round'], mak_20['Accuracy_Smoothed'], label='Our 20', color='blue')
plt.plot(mak_10['Round'], mak_10['Accuracy_Smoothed'], label='Our 10', color='black')


# Formatting the Plot
plt.grid(True)
plt.title("Non-IID Data CNN with 0.9 Stragglers")
plt.xlabel('Global Iteration')
plt.ylabel('Validation Accuracy')
plt.legend()

# Save the Plot
# plt.savefig("Non_IID_CNN.png", dpi=300, bbox_inches='tight', format='png')

# Show the Plot
plt.show()

# %% [markdown]
# # CNN winth (0.8) Stargglers and IID Data and Cifar10

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_IID/0.8_1/Main_log_2025-03-26_05-24-PM.csv')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
# df_main_5 = pd.read_csv('')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_IID/FIRST_Exception/0.8strg_10sync/MAK_log_2025-03-26_06-05-PM.csv')
# df_Mak_20 = pd.read_csv('')
# df_Mak_30 = pd.read_csv('')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
# df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
# df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
#         color='blue', linestyle='--', marker='s',
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.8) Stragglers IID Data')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
# df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
# df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
#         color='blue', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.8) Stragglers IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %% [markdown]
# # CNN winth (0.8) Stargglers and Non-IID(0.01) Data and Cifar10

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_Non_IID/0.8_1/Main_log_2025-03-26_08-48-PM.csv')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
# df_main_5 = pd.read_csv('')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_Non_IID/FIRST_Exception/0.8strg_10sync/MAK_log_2025-03-26_09-28-PM.csv')
# df_Mak_20 = pd.read_csv('')
# df_Mak_30 = pd.read_csv('')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
# df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
# df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
#         color='blue', linestyle='--', marker='s',
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.8) Stragglers Non IID Data')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
# df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
# df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
#         color='blue', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.8) Stragglers Non IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %% [markdown]
# # CNN winth (0.5) Stargglers and IID Data and Cifar10

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_IID/0.5_1/Main_log_2025-03-26_11-25-PM.csv')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
# df_main_5 = pd.read_csv('')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_IID/FIRST_Exception/0.5strg_10sync/MAK_log_2025-03-27_09-52-AM.csv')
df_Mak_10_delay = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_IID_Delayed/FIRST_Exception/0.5strg_10sync/MAK_log_2025-03-27_10-38-AM.csv')
# df_Mak_20 = pd.read_csv('')
# df_Mak_30 = pd.read_csv('')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
# df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
df_Mak_10_delay['Train Loss Smoothed'] = df_Mak_10_delay['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
# df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
#         color='blue', linestyle='--', marker='s',
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Train Loss Smoothed'], 
        color='black', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync Delay')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.5) Stragglers IID Data')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
# df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
df_Mak_10_delay['Accuracy Smoothed'] = df_Mak_10_delay['Accuracy'].rolling(window=window_size).mean()
# df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
#         color='blue', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Accuracy Smoothed'], 
        color='black', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync Delay')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.8) Stragglers IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %% [markdown]
# # CNN winth (0.5) Stargglers and Non-IID (0.01) Data and Cifar10

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_Non_IID_100/0.5_1/Main_log_2025-03-27_01-48-PM.csv')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
# df_main_5 = pd.read_csv('')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_Non_IID_100/FIRST_Exception/0.5strg_10sync/MAK_log_2025-03-27_02-28-PM.csv')
df_Mak_10_delay = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_Non_IID_100/FIRST_Completed/0.5strg_10sync/MAK_log_2025-03-27_02-28-PM.csv')
# df_Mak_20 = pd.read_csv('')
# df_Mak_30 = pd.read_csv('')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
# df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
df_Mak_10_delay['Train Loss Smoothed'] = df_Mak_10_delay['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
# df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
#         color='blue', linestyle='--', marker='s',
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Train Loss Smoothed'], 
        color='black', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync Delay')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.5) Stragglers Non_IID Data')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
# df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
df_Mak_10_delay['Accuracy Smoothed'] = df_Mak_10_delay['Accuracy'].rolling(window=window_size).mean()
# df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
#         color='blue', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Accuracy Smoothed'], 
        color='black', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync Delay')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.5) Stragglers Non-IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %% [markdown]
# # CNN winth (0.6) Stargglers and IID Data and Cifar10

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_IID/0.6_1/Main_log_2025-03-27_03-57-PM.csv')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
# df_main_5 = pd.read_csv('')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_IID/FIRST_Completed/0.6strg_10sync/MAK_log_2025-03-27_04-38-PM.csv')
df_Mak_10_delay = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_IID/FIRST_Exception/0.6strg_10sync/MAK_log_2025-03-27_04-38-PM.csv')
# df_Mak_20 = pd.read_csv('')
# df_Mak_30 = pd.read_csv('')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
# df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
df_Mak_10_delay['Train Loss Smoothed'] = df_Mak_10_delay['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
# df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
#         color='blue', linestyle='--', marker='s',
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Train Loss Smoothed'], 
        color='black', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync Delay')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.6) Stragglers IID Data')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
# df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
df_Mak_10_delay['Accuracy Smoothed'] = df_Mak_10_delay['Accuracy'].rolling(window=window_size).mean()
# df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
#         color='blue', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Accuracy Smoothed'], 
        color='black', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync Delay')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.6) Stragglers Non-IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %% [markdown]
# # CNN winth (0.6) Stargglers and Non-IID Data and Cifar10

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

# # Load CSV files
df_main_1 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/CNN_Non_IID/0.6_1/Main_log_2025-03-27_05-23-PM.csv')
# df_main_3  = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Main_logs\\Non_IID\\New_300\\0.3_3\\Main_log_2025-03-19_02-30-PM.csv')
# df_main_5 = pd.read_csv('')
df_Mak_10 = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_Non_IID/FIRST_Completed/0.6strg_10sync/MAK_log_2025-03-27_06-03-PM.csv')
df_Mak_10_delay = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/CNN_Non_IID/FIRST_Exception/0.6strg_10sync/MAK_log_2025-03-27_06-03-PM.csv')
# df_Mak_20 = pd.read_csv('')
# df_Mak_30 = pd.read_csv('')
# df_Mak_7 = pd.read_csv('C:\\Users\\wahab\\Desktop\\SALF\\SALF\\Make_Non_IID\\New_300\\Fully\\FIRST_Completed\\0.3strg_7sync\\MAK_log_2025-03-19_12-39-PM.csv')
# Apply moving average
plt.figure(figsize=(10, 6))
markstep = 10
window_size = 10 # Adjust as needed
df_main_1['Train Loss Smoothed'] = df_main_1['Train Loss'].rolling(window=window_size).mean()
# df_main_3['Train Loss Smoothed'] = df_main_3['Train Loss'].rolling(window=window_size).mean()
# df_main_5['Train Loss Smoothed'] = df_main_5['Train Loss'].rolling(window=window_size).mean()
df_Mak_10['Train Loss Smoothed'] = df_Mak_10['Train Loss'].rolling(window=window_size).mean()
df_Mak_10_delay['Train Loss Smoothed'] = df_Mak_10_delay['Train Loss'].rolling(window=window_size).mean()
# df_Mak_7['Train Loss Smoothed'] = df_Mak_7['Train Loss'].rolling(window=window_size).mean()
# df_Mak_30['Train Loss Smoothed'] = df_Mak_30['Train Loss'].rolling(window=window_size).mean()

# Plot smoothed loss
# plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], color='blue', linestyle='-', marker='o', label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], color='blue', linestyle='-.', marker='d', label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], color='blue', linestyle='--', marker='s', label='Train Loss SALF layer 5')

# plt.plot(df_Mak_5['Round'], df_Mak_5['Train Loss Smoothed'], color='red', linestyle='-', marker='o', label='Train Loss 5 Sync')
# plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], color='red', linestyle='-.', marker='d', label='Train Loss 10 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], color='red', linestyle='--', marker='s', label='Train Loss 20 Sync')

# Blue lines for SALF layers
plt.plot(df_main_1['Round'], df_main_1['Train Loss Smoothed'], 
        color='blue', linestyle='-',  marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Train Loss Smoothed'], 
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Train Loss SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Train Loss Smoothed'], 
#         color='blue', linestyle='--', marker='s',
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss SALF layer 5')

# # Red lines for Sync settings
plt.plot(df_Mak_10['Round'], df_Mak_10['Train Loss Smoothed'], 
        color='red', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Train Loss Smoothed'], 
        color='black', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 10 Sync Delay')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Train Loss Smoothed'], 
#          color='black', linestyle='-.', marker='d', 
#          markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 7 Sync')
# plt.plot(df_Mak_20['Round'], df_Mak_20['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 20 Sync')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Train Loss Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Train Loss 30 Sync')


# plt.savefig("train_loss_plot.png", dpi=300, bbox_inches='tight', format='png')


# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Train Loss  ')
plt.title('Training Loss over Rounds for (0.6) Stragglers Non-IID Data')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
df_main_1['Accuracy Smoothed'] = df_main_1['Accuracy'].rolling(window=window_size).mean()
# df_main_3['Accuracy Smoothed'] = df_main_3['Accuracy'].rolling(window=window_size).mean()
# df_main_5['Accuracy Smoothed'] = df_main_5['Accuracy'].rolling(window=window_size).mean()
# df_Mak_7['Accuracy Smoothed'] = df_Mak_7['Accuracy'].rolling(window=window_size).mean()
df_Mak_10['Accuracy Smoothed'] = df_Mak_10['Accuracy'].rolling(window=window_size).mean()
df_Mak_10_delay['Accuracy Smoothed'] = df_Mak_10_delay['Accuracy'].rolling(window=window_size).mean()
# df_Mak_30['Accuracy Smoothed'] = df_Mak_30['Accuracy'].rolling(window=window_size).mean()

# Plot smoothed validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(df_main_1['Round'], df_main_1['Accuracy Smoothed'],
        color='blue', linestyle='-', marker='o', 
        markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 1')
# plt.plot(df_main_3['Round'], df_main_3['Accuracy Smoothed'],
#         color='blue', linestyle='-.', marker='d', 
#         markersize=3, linewidth=1, alpha=0.8, markevery=markstep,label='Validation Accuracy SALF layer 3')
# plt.plot(df_main_5['Round'], df_main_5['Accuracy Smoothed'], 
#         color='blue', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy SALF layer 5')
# plt.plot(df_Mak_7['Round'], df_Mak_7['Accuracy Smoothed'], 
#         color='black', linestyle='-', marker='o', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 5 Sync')
plt.plot(df_Mak_10['Round'], df_Mak_10['Accuracy Smoothed'], 
        color='red', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync')

plt.plot(df_Mak_10_delay['Round'], df_Mak_10_delay['Accuracy Smoothed'], 
        color='black', linestyle='-.', marker='d', 
        markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 10 Sync Delay')
# plt.plot(df_Mak_30['Round'], df_Mak_30['Accuracy Smoothed'], 
#         color='red', linestyle='--', marker='s', 
#         markersize=3, linewidth=1, alpha=0.8,markevery=markstep, label='Validation Accuracy 30 Sync')

# Labels and Title
plt.xlabel('Rounds')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracy over Rounds (0.6) Stragglers Non-IID Data')
plt.grid(True)
plt.legend()

# Save the figure BEFORE plt.show()
# plt.savefig("Non_IID_Fully_0.9.png", dpi=300, bbox_inches='tight', format='png')

# Now show the plot
plt.show()

# %%
import csv
import matplotlib.pyplot as plt 
import pandas as pd 

first = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_12345Seed_0.6strg_10sync/MAK_log_2025-03-30_02-17-PM.csv')
# second = pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_12345Seed_0.6strg_10sync/MAK_log_2025-03-30_02-52-PM.csv')

plt.plot(first['Round'], first['Accuracy'], label = 'first 2')
# plt.plot(second['Round'], second['Accuracy'], label = 'Second 3')

plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.grid('True')
print(f"for 2 second: {max(first['Accuracy'])}")
# print(f"for 3 second: {max(second['Accuracy'])}")
# Out:
# for 2 second: 36.18

# %%
import matplotlib.pyplot as plt
import pandas as pd  

# Load CSV files
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_11-56-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_11-27-AM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-30_03-32-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_12345Seed_0.6strg_10sync/MAK_log_2025-03-30_02-17-PM.csv')
]

SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_02-04-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_01-34-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.6strg_10sync/MAK_log_2025-03-30_10-52-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-30_04-11-PM.csv')
]

SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_02-47-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_03-21-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.6strg_10sync/MAK_log_2025-03-31_09-41-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-31_10-28-AM.csv')
]

# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
# Plot the average accuracy
plt.plot(average_accuracy_salf_001, label='SALF_0.01')
plt.plot(average_accuracy_mak_001, label='MAK_0.01')

plt.plot(average_accuracy_salf_005, label='SALF_0.05')
plt.plot(average_accuracy_mak_005, label='MAK_0.05')

plt.plot(average_accuracy_salf_01, label='SALF_0.1')
plt.plot(average_accuracy_mak_01, label='MAK_0.1')

# Add labels and grid
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.title('0.6 Stragglers')

# Display the plot
plt.show()

# Print max accuracy for both files
print(f"Max accuracy of SALF 0.01: {max(average_accuracy_salf_001)}")
print(f"Max accuracy of MAK 0.01: {max(average_accuracy_mak_001)}")
print(f"Max accuracy of SALF 0.05: {max(average_accuracy_salf_005)}")
print(f"Max accuracy of MAK 0.05: {max(average_accuracy_mak_005)}")
print(f"Max accuracy of SALF 0.1: {max(average_accuracy_salf_01)}")
print(f"Max accuracy of MAK 0.1: {max(average_accuracy_mak_01)}")
# Out:
# Max accuracy of SALF 0.01: 40.510000000000005
# Max accuracy of MAK 0.01: 38.435
# Max accuracy of SALF 0.05: 50.215
# Max accuracy of MAK 0.05: 43.18
# Max accuracy of SALF 0.1: 51.595
# Max accuracy of MAK 0.1: 48.974999999999994

# %%
import matplotlib.pyplot as plt
import pandas as pd  

# Load CSV files
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-28_04-39-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-28_04-00-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.7strg_10sync/MAK_log_2025-03-31_11-45-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.7strg_10sync/MAK_log_2025-03-31_11-03-AM.csv')
]

SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-28_05-11-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-28_05-41-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.7strg_10sync/MAK_log_2025-03-31_12-28-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.7strg_12sync/MAK_log_2025-03-31_01-20-PM.csv')
]

SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-29_12-43-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-29_12-04-AM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.7strg_20sync/MAK_log_2025-04-01_11-33-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.7strg_20sync/MAK_log_2025-04-02_12-37-AM.csv')
]

# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
# Plot the average accuracy
plt.plot(average_accuracy_salf_001, label='SALF_0.01')
plt.plot(average_accuracy_mak_001, label='MAK_0.01')

plt.plot(average_accuracy_salf_005, label='SALF_0.05')
plt.plot(average_accuracy_mak_005, label='MAK_0.05')

plt.plot(average_accuracy_salf_01, label='SALF_0.1')
plt.plot(average_accuracy_mak_01, label='MAK_0.1')

# Add labels and grid
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.title('0.7 Stragglers')

# Display the plot
plt.show()

# Print max accuracy for both files
print(f"Max accuracy of SALF 0.01: {max(average_accuracy_salf_001)}")
print(f"Max accuracy of MAK 0.01: {max(average_accuracy_mak_001)}")
print(f"Max accuracy of SALF 0.05: {max(average_accuracy_salf_005)}")
print(f"Max accuracy of MAK 0.05: {max(average_accuracy_mak_005)}")
print(f"Max accuracy of SALF 0.1: {max(average_accuracy_salf_01)}")
print(f"Max accuracy of MAK 0.1: {max(average_accuracy_mak_01)}")
# Out:
# Max accuracy of SALF 0.01: 38.540000000000006
# Max accuracy of MAK 0.01: 39.14
# Max accuracy of SALF 0.05: 48.345
# Max accuracy of MAK 0.05: 44.099999999999994
# Max accuracy of SALF 0.1: 50.8
# Max accuracy of MAK 0.1: 49.725

# %%
import matplotlib.pyplot as plt
import pandas as pd  

# Load CSV files
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_06-10-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_02-39-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.8strg_10sync/MAK_log_2025-03-31_05-53-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.8strg_10sync/MAK_log_2025-03-31_06-40-PM.csv')
]

SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_03-42-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_03-12-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.8strg_20sync/MAK_log_2025-04-01_10-25-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.8strg_20sync/MAK_log_2025-04-01_09-44-AM.csv')
]

SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_08-52-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_04-12-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.8strg_10sync/MAK_log_2025-04-01_11-18-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.8strg_10sync/MAK_log_2025-04-01_11-59-AM.csv')
]

# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
# Plot the average accuracy
plt.plot(average_accuracy_salf_001, label='SALF_0.01')
plt.plot(average_accuracy_mak_001, label='MAK_0.01')

plt.plot(average_accuracy_salf_005, label='SALF_0.05')
plt.plot(average_accuracy_mak_005, label='MAK_0.05')

plt.plot(average_accuracy_salf_01, label='SALF_0.1')
plt.plot(average_accuracy_mak_01, label='MAK_0.1')

# Add labels and grid
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.title('0.8 Stragglers')

# Display the plot
plt.show()

# Print max accuracy for both files
print(f"Max accuracy of SALF 0.01: {max(average_accuracy_salf_001)}")
print(f"Max accuracy of MAK 0.01: {max(average_accuracy_mak_001)}")
print(f"Max accuracy of SALF 0.05: {max(average_accuracy_salf_005)}")
print(f"Max accuracy of MAK 0.05: {max(average_accuracy_mak_005)}")
print(f"Max accuracy of SALF 0.1: {max(average_accuracy_salf_01)}")
print(f"Max accuracy of MAK 0.1: {max(average_accuracy_mak_01)}")
# Out:
# Max accuracy of SALF 0.01: 36.66
# Max accuracy of MAK 0.01: 39.555
# Max accuracy of SALF 0.05: 48.18
# Max accuracy of MAK 0.05: 43.754999999999995
# Max accuracy of SALF 0.1: 51.25
# Max accuracy of MAK 0.1: 49.305

# %%
plt.plot(SALF_005[0]['Accuracy'], label ='first one')
plt.plot(SALF_005[1]['Accuracy'], label = 'second')
# plt.p

# %%
plt.plot(MAK_005[0]['Accuracy'], label ='first one')
plt.plot(MAK_005[1]['Accuracy'], label = 'second')

# %%
merged_df = pd.merge(SALF_005[0], SALF_005[1], on="Round", suffixes=('_1', '_2'))
# Compute mean and standard deviation per round
merged_df['Avg_Accuracy'] = merged_df[['Accuracy_1', 'Accuracy_2']].mean(axis=1)
merged_df['Std_Accuracy'] = merged_df[['Accuracy_1', 'Accuracy_2']].std(axis=1)
print(max(merged_df['Avg_Accuracy']))
print(merged_df.tail())
# Out:
# 48.18
#      Round  Train Loss_1  Accuracy_1  Train Loss_2  Accuracy_2  Avg_Accuracy  \
# 195    195          0.31       48.70          0.43       46.82        47.760
# 196    196          0.31       48.91          0.42       46.76        47.835
# 197    197          0.32       48.80          0.43       47.09        47.945
# 198    198          0.31       48.79          0.42       46.98        47.885
# 199    199          0.31       49.14          0.43       47.22        48.180
#
#      Std_Accuracy
# 195      1.329361
# 196      1.520280
# 197      1.209153
# 198      1.279863
# 199      1.357645

# %%
import matplotlib.pyplot as plt
import pandas as pd  

# Load CSV files
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.9Str_1lyr/Main_log_2025-03-29_09-58-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-29_09-29-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.9strg_10sync/MAK_log_2025-04-01_12-48-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.9strg_10sync/MAK_log_2025-04-01_05-07-PM.csv')
]

SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.9Str_1lyr/Main_log_2025-03-29_11-00-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-29_11-30-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.9strg_15sync/MAK_log_2025-04-01_06-05-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.9strg_20sync/MAK_log_2025-04-01_06-51-PM.csv')
]

SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_12345Seed_0.9Str_1lyr/Main_log_2025-03-30_01-31-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-30_12-56-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.9strg_20sync/MAK_log_2025-04-01_10-12-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.9strg_20sync/MAK_log_2025-04-01_09-30-PM.csv')
]

# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
# Plot the average accuracy
plt.plot(average_accuracy_salf_001, label='SALF_0.01')
plt.plot(average_accuracy_mak_001, label='MAK_0.01')

plt.plot(average_accuracy_salf_005, label='SALF_0.05')
plt.plot(average_accuracy_mak_005, label='MAK_0.05')

plt.plot(average_accuracy_salf_01, label='SALF_0.1')
plt.plot(average_accuracy_mak_01, label='MAK_0.1')

# Add labels and grid
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.title('0.9 Stragglers')

# Display the plot
plt.show()

# Print max accuracy for both files
print(f"Max accuracy of SALF 0.01: {max(average_accuracy_salf_001)}")
print(f"Max accuracy of MAK 0.01: {max(average_accuracy_mak_001)}")
print(f"Max accuracy of SALF 0.05: {max(average_accuracy_salf_005)}")
print(f"Max accuracy of MAK 0.05: {max(average_accuracy_mak_005)}")
print(f"Max accuracy of SALF 0.1: {max(average_accuracy_salf_01)}")
print(f"Max accuracy of MAK 0.1: {max(average_accuracy_mak_01)}")
# Out:
# Max accuracy of SALF 0.01: 34.195
# Max accuracy of MAK 0.01: 39.80500000000001
# Max accuracy of SALF 0.05: 47.335
# Max accuracy of MAK 0.05: 45.7
# Max accuracy of SALF 0.1: 48.955
# Max accuracy of MAK 0.1: 49.915000000000006

# %%
MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.9strg_20sync/MAK_log_2025-04-01_10-12-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.9strg_20sync/MAK_log_2025-04-01_09-30-PM.csv')
]

# plt.plot(MAK_01[0], label = 'first')
# plt.plot(MAK_01[1], label = 'second')
# plt.legend()
max(MAK_01[0]['Accuracy'])
# max(MAK_01[1]['Accuracy'])
# Out:
# 50.31

# %%
print(max(MAK_001[0]['Accuracy']))
print(max(MAK_001[1]['Accuracy']))
print(max(SALF_001[0]['Accuracy']))
print(max(SALF_001[1]['Accuracy']))
# Out:
# 41.71
# 38.13
# 34.77
# 33.83

# %%
print(max(MAK_005[0]['Accuracy']))
print(max(MAK_005[1]['Accuracy']))
print(max(SALF_005[0]['Accuracy']))
print(max(SALF_005[1]['Accuracy']))
# Out:
# 46.28
# 45.72
# 48.25
# 46.83

# %%
print(max(MAK_01[0]['Accuracy']))
print(max(MAK_01[1]['Accuracy']))
print(max(SALF_01[0]['Accuracy']))
print(max(SALF_01[1]['Accuracy']))
# Out:
# 50.31
# 49.63
# 48.53
# 49.66

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.9Str_1lyr/Main_log_2025-03-29_09-58-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-29_09-29-PM.csv')
]
up_to_layer_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.9Str_3lyr/Main_log_2025-04-02_10-17-AM.csv')

plt.plot(SALF_001[0]['Accuracy'], label = 'first 1 layer')
plt.plot(SALF_001[1]['Accuracy'], label = 'Second 1 layer')
plt.plot(MAK_001[1]['Accuracy'], label = 'Mak')
plt.plot(up_to_layer_3['Accuracy'], label = '3 layer')
plt.legend()

# %% [markdown]
# # Final Compiled

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_11-56-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_11-27-AM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-30_03-32-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_12345Seed_0.6strg_10sync/MAK_log_2025-03-30_02-17-PM.csv')
]

SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-02_03-34-PM.csv')

MAK_001_30 = [
    pd.read_csv(''),
    pd.read_csv('')
]

# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)
average_accuracy_mak_001_30 = sum(df['Accuracy'] for df in MAK_001_30) / len(MAK_001_30)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1',marker="*", markevery=10)
plt.plot(average_accuracy_mak_001, label ='MAK',marker="s", markevery=10)
plt.plot(average_accuracy_mak_001_30, label ='MAK 30',marker="*", markevery=10)
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3',marker="d", markevery=10)
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.6' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
print(f"MAK 30 : {max(average_accuracy_mak_001_30)}")
# Out:
# SALF layer 1: 40.510000000000005
# SALF layer 3: 39.21
# MAK : 38.435

# %%
SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_02-04-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_01-34-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.6strg_10sync/MAK_log_2025-03-30_10-52-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-30_04-11-PM.csv')
]

SALF_005_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-02_04-03-PM.csv')

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

plt.plot(average_accuracy_salf_005, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_005, label ='MAK')
plt.plot(SALF_005_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.6' Stragglers with '0.05' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_005)}")
print(f"SALF layer 3: {max(SALF_005_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_005)}")
# Out:
# SALF layer 1: 50.215
# SALF layer 3: 49.21
# MAK : 43.18

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_02-47-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_03-21-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.6strg_10sync/MAK_log_2025-03-31_09-41-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-31_10-28-AM.csv')
]


SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-02_04-40-PM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.6' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")
# Out:
# SALF layer 1: 51.595
# SALF layer 3: 52.17
# MAK : 48.974999999999994

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-28_04-39-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-28_04-00-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.7strg_10sync/MAK_log_2025-03-31_11-45-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.7strg_10sync/MAK_log_2025-03-31_11-03-AM.csv')
]


SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-02_01-59-PM.csv')

average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_001, label ='MAK')
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.7' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
# Out:
# SALF layer 1: 38.540000000000006
# SALF layer 3: 35.95
# MAK : 39.14

# %%
SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-28_05-11-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-28_05-41-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.7strg_10sync/MAK_log_2025-03-31_12-28-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.7strg_12sync/MAK_log_2025-03-31_01-20-PM.csv')
]

SALF_005_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-02_02-35-PM.csv')

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

plt.plot(average_accuracy_salf_005, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_005, label ='MAK')
plt.plot(SALF_005_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.7' Stragglers with '0.05' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_005)}")
print(f"SALF layer 3: {max(SALF_005_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_005)}")
# Out:
# SALF layer 1: 48.345
# SALF layer 3: 47.28
# MAK : 44.099999999999994

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-29_12-43-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-29_12-04-AM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.7strg_20sync/MAK_log_2025-04-01_11-33-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.7strg_20sync/MAK_log_2025-04-02_12-37-AM.csv')
]

SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-02_03-04-PM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.7' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")
# Out:
# SALF layer 1: 50.8
# SALF layer 3: 50.73
# MAK : 49.725

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_06-10-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_02-39-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.8strg_10sync/MAK_log_2025-03-31_05-53-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.8strg_10sync/MAK_log_2025-03-31_06-40-PM.csv')
]

SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.8Str_3lyr/Main_log_2025-04-02_12-06-PM.csv')

average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_001, label ='MAK')
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.8' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
# Out:
# SALF layer 1: 36.66
# SALF layer 3: 32.67
# MAK : 39.555

# %%
SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_03-42-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_03-12-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.8strg_20sync/MAK_log_2025-04-01_10-25-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.8strg_20sync/MAK_log_2025-04-01_09-44-AM.csv')
]

SALF_005_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.8Str_3lyr/Main_log_2025-04-02_12-35-PM.csv')

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

plt.plot(average_accuracy_salf_005, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_005, label ='MAK')
plt.plot(SALF_005_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.8' Stragglers with '0.05' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_005)}")
print(f"SALF layer 3: {max(SALF_005_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_005)}")
# Out:
# SALF layer 1: 48.18
# SALF layer 3: 46.67
# MAK : 43.754999999999995

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_08-52-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_04-12-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.8strg_10sync/MAK_log_2025-04-01_11-18-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.8strg_10sync/MAK_log_2025-04-01_11-59-AM.csv')
]

SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.8Str_3lyr/Main_log_2025-04-02_01-12-PM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.8' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")

print("Salf")
print(max(SALF_01[0]['Accuracy']))
print(max(SALF_01[1]['Accuracy']))
print("MAK")
print(max(MAK_01[0]['Accuracy']))
print(max(MAK_01[1]['Accuracy']))
# Out:
# SALF layer 1: 51.25
# SALF layer 3: 48.47
# MAK : 49.305
# Salf
# 50.68
# 51.89
# MAK
# 49.83
# 48.91

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.9Str_1lyr/Main_log_2025-03-29_09-58-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-29_09-29-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.9strg_10sync/MAK_log_2025-04-01_12-48-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.9strg_10sync/MAK_log_2025-04-01_05-07-PM.csv')
]


SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.9Str_3lyr/Main_log_2025-04-02_10-17-AM.csv')

# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_001, label ='MAK')
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.9' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
# Out:
# SALF layer 1: 34.195
# SALF layer 3: 29.03
# MAK : 39.80500000000001

# %%
SALF_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.9Str_1lyr/Main_log_2025-03-29_11-00-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-29_11-30-PM.csv')
]

MAK_005 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.9strg_15sync/MAK_log_2025-04-01_06-05-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.9strg_20sync/MAK_log_2025-04-01_06-51-PM.csv')
]

SALF_005_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.9Str_3lyr/Main_log_2025-04-02_11-07-AM.csv')

average_accuracy_salf_005 = sum(df['Accuracy'] for df in SALF_005) / len(SALF_005)
average_accuracy_mak_005 = sum(df['Accuracy'] for df in MAK_005) / len(MAK_005)

plt.plot(average_accuracy_salf_005, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_005, label ='MAK')
plt.plot(SALF_005_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.9' Stragglers with '0.05' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_005)}")
print(f"SALF layer 3: {max(SALF_005_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_005)}")
# Out:
# SALF layer 1: 47.335
# SALF layer 3: 44.35
# MAK : 45.7

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_12345Seed_0.9Str_1lyr/Main_log_2025-03-30_01-31-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-30_12-56-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.9strg_20sync/MAK_log_2025-04-01_10-12-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.9strg_20sync/MAK_log_2025-04-01_09-30-PM.csv')
]

SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.9Str_3lyr/Main_log_2025-04-02_11-36-AM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.9' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")
# Out:
# SALF layer 1: 48.955
# SALF layer 3: 47.06
# MAK : 49.915000000000006

# %% [markdown]
# # Confirmation

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_11-56-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_11-27-AM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-30_03-32-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_12345Seed_0.6strg_10sync/MAK_log_2025-03-30_02-17-PM.csv')
]

MAK_001_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.6strg_30sync/MAK_log_2025-04-02_07-02-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.6strg_30sync/MAK_log_2025-04-02_07-03-PM.csv')
]
  

SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-02_03-34-PM.csv')


# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)
average_accuracy_mak_001_30 = sum(df['Accuracy'] for df in MAK_001_30) / len(MAK_001_30)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1',marker="*", markevery=10)
plt.plot(average_accuracy_mak_001, label ='MAK',marker="s", markevery=10)
plt.plot(average_accuracy_mak_001_30, label ='MAK 30',marker="*", markevery=10)
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3',marker="d", markevery=10)
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.6' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
print(f"MAK 30 : {max(average_accuracy_mak_001_30)}")
print(f"MAK 30 first: {max(MAK_001_30[0]['Accuracy'])}")
print(f"MAK 30 second : {max(MAK_001_30[1]['Accuracy'])}")
# Out:
# SALF layer 1: 40.510000000000005
# SALF layer 3: 39.21
# MAK : 38.435
# MAK 30 : 34.745
# MAK 30 first: 34.34
# MAK 30 second : 39.76

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-28_04-39-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-28_04-00-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.7strg_10sync/MAK_log_2025-03-31_11-45-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.7strg_10sync/MAK_log_2025-03-31_11-03-AM.csv')
]


MAK_001_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.7strg_30sync/MAK_log_2025-04-02_08-18-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.7strg_30sync/MAK_log_2025-04-02_08-18-PM.csv')
]

SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-02_01-59-PM.csv')

average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)
average_accuracy_mak_001_30 = sum(df['Accuracy'] for df in MAK_001_30) / len(MAK_001_30)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_001, label ='MAK')
plt.plot(average_accuracy_mak_001_30, label ='MAK 30')
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.7' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
print(f"MAK 30 : {max(average_accuracy_mak_001_30)}")
print(f"MAK 30 first: {max(MAK_001_30[0]['Accuracy'])}")
print(f"MAK 30 second : {max(MAK_001_30[1]['Accuracy'])}")
# Out:
# SALF layer 1: 38.540000000000006
# SALF layer 3: 35.95
# MAK : 39.14
# MAK 30 : 38.205
# MAK 30 first: 37.04
# MAK 30 second : 41.06

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_06-10-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_02-39-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.8strg_10sync/MAK_log_2025-03-31_05-53-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.8strg_10sync/MAK_log_2025-03-31_06-40-PM.csv')
]

MAK_001_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.8strg_30sync/MAK_log_2025-04-03_09-31-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.8strg_30sync/MAK_log_2025-04-03_09-31-AM.csv')
]

SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.8Str_3lyr/Main_log_2025-04-02_12-06-PM.csv')

average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)
average_accuracy_mak_001_30 = sum(df['Accuracy'] for df in MAK_001_30) / len(MAK_001_30)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_001, label ='MAK')
plt.plot(average_accuracy_mak_001_30, label ='MAK 30')
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.8' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
print(f"MAK 30 : {max(average_accuracy_mak_001)}")
print(f"MAK 30 first: {max(MAK_001_30[0]['Accuracy'])}")
print(f"MAK 30 second : {max(MAK_001_30[1]['Accuracy'])}")
# Out:
# SALF layer 1: 36.66
# SALF layer 3: 32.67
# MAK : 39.555
# MAK 30 : 39.555
# MAK 30 first: 37.62
# MAK 30 second : 41.01

# %%
SALF_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.9Str_1lyr/Main_log_2025-03-29_09-58-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-29_09-29-PM.csv')
]

MAK_001 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.9strg_10sync/MAK_log_2025-04-01_12-48-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.9strg_10sync/MAK_log_2025-04-01_05-07-PM.csv')
]


MAK_001_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_1234Seed_0.9strg_30sync/MAK_log_2025-04-03_10-13-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.01dir_5555Seed_0.9strg_30sync/MAK_log_2025-04-03_10-14-AM.csv')
]

SALF_001_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.01dir_1234Seed_0.9Str_3lyr/Main_log_2025-04-02_10-17-AM.csv')

# Compute the average accuracy using a loop
average_accuracy_salf_001 = sum(df['Accuracy'] for df in SALF_001) / len(SALF_001)
average_accuracy_mak_001 = sum(df['Accuracy'] for df in MAK_001) / len(MAK_001)
average_accuracy_mak_001_30 = sum(df['Accuracy'] for df in MAK_001_30) / len(MAK_001_30)

plt.plot(average_accuracy_salf_001, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_001, label ='MAK')
plt.plot(average_accuracy_mak_001_30, label ='MAK 30')
plt.plot(SALF_001_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.9' Stragglers with '0.01' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_001)}")
print(f"SALF layer 3: {max(SALF_001_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_001)}")
print(f"MAK 30 : {max(average_accuracy_mak_001_30)}")
print(f"MAK 30 first: {max(MAK_001_30[0]['Accuracy'])}")
print(f"MAK 30 second : {max(MAK_001_30[1]['Accuracy'])}")
# Out:
# SALF layer 1: 34.195
# SALF layer 3: 29.03
# MAK : 39.80500000000001
# MAK 30 : 39.765
# MAK 30 first: 38.15
# MAK 30 second : 41.64

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.6Str_1lyr/Main_log_2025-03-28_02-47-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_03-21-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.6strg_10sync/MAK_log_2025-03-31_09-41-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.6strg_10sync/MAK_log_2025-03-31_10-28-AM.csv')
]

MAK_01_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.6strg_30sync/MAK_log_2025-04-03_11-14-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.6strg_30sync/MAK_log_2025-04-03_11-13-AM.csv')
]


SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-02_04-40-PM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
average_accuracy_mak_01_30 = sum(df['Accuracy'] for df in MAK_01_30) / len(MAK_01_30)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(average_accuracy_mak_01_30, label ='MAK 30')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.6' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")
print(f"MAK 30 : {max(average_accuracy_mak_01_30)}")
# Out:
# SALF layer 1: 51.595
# SALF layer 3: 52.17
# MAK : 48.974999999999994
# MAK 30 : 46.435

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.7Str_1lyr/Main_log_2025-03-29_12-43-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-29_12-04-AM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.7strg_20sync/MAK_log_2025-04-01_11-33-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.7strg_20sync/MAK_log_2025-04-02_12-37-AM.csv')
]

MAK_01_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.7strg_30sync/MAK_log_2025-04-03_11-14-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.7strg_30sync/MAK_log_2025-04-03_11-15-AM.csv')
]

SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-02_03-04-PM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
average_accuracy_mak_01_30 = sum(df['Accuracy'] for df in MAK_01_30) / len(MAK_01_30)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(average_accuracy_mak_01_30, label ='MAK 30')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.7' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")
print(f"MAK 30 : {max(average_accuracy_mak_01_30)}")
# Out:
# SALF layer 1: 50.8
# SALF layer 3: 50.73
# MAK : 49.725
# MAK 30 : 48.239999999999995

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.8Str_1lyr/Main_log_2025-03-29_08-52-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.8Str_1lyr/Main_log_2025-03-29_04-12-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.8strg_10sync/MAK_log_2025-04-01_11-18-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.8strg_10sync/MAK_log_2025-04-01_11-59-AM.csv')
]

MAK_01_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.8strg_30sync/MAK_log_2025-04-03_11-16-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.8strg_30sync/MAK_log_2025-04-03_11-16-AM.csv')
]

SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.8Str_3lyr/Main_log_2025-04-02_01-12-PM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
average_accuracy_mak_01_30 = sum(df['Accuracy'] for df in MAK_01_30) / len(MAK_01_30)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(average_accuracy_mak_01_30, label ='MAK 30')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.8' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")
print(f"MAK 30 : {max(average_accuracy_mak_01_30)}")

# print("Salf")
# print(max(SALF_01[0]['Accuracy']))
# print(max(SALF_01[1]['Accuracy']))
# print("MAK")
# print(max(MAK_01[0]['Accuracy']))
# print(max(MAK_01[1]['Accuracy']))
# Out:
# SALF layer 1: 51.25
# SALF layer 3: 48.47
# MAK : 49.305
# MAK 30 : 48.4

# %%
SALF_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_12345Seed_0.9Str_1lyr/Main_log_2025-03-30_01-31-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_5555Seed_0.9Str_1lyr/Main_log_2025-03-30_12-56-PM.csv')
]

MAK_01 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.9strg_20sync/MAK_log_2025-04-01_10-12-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.9strg_20sync/MAK_log_2025-04-01_09-30-PM.csv')
]

MAK_01_30 = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_5555Seed_0.9strg_30sync/MAK_log_2025-04-03_11-17-AM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.1dir_1234Seed_0.9strg_30sync/MAK_log_2025-04-03_11-17-AM.csv')
]

SALF_01_3 = pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.1dir_1234Seed_0.9Str_3lyr/Main_log_2025-04-02_11-36-AM.csv')

average_accuracy_salf_01 = sum(df['Accuracy'] for df in SALF_01) / len(SALF_01)
average_accuracy_mak_01 = sum(df['Accuracy'] for df in MAK_01) / len(MAK_01)
average_accuracy_mak_01_30 = sum(df['Accuracy'] for df in MAK_01_30) / len(MAK_01_30)

plt.plot(average_accuracy_salf_01, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak_01, label ='MAK')
plt.plot(average_accuracy_mak_01_30, label ='MAK 30')
plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.9' Stragglers with '0.1' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_01)}")
print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"MAK : {max(average_accuracy_mak_01)}")
print(f"MAK 30 : {max(average_accuracy_mak_01_30)}")
# Out:
# SALF layer 1: 48.955
# SALF layer 3: 47.06
# MAK : 49.915000000000006
# MAK 30 : 50.425

# %% [markdown]
# # Extreme Case (0.001)

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

def moving_average(data, window_size=10):
    return data.rolling(window=window_size, min_periods=1).mean()

# %%
SALF_1 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.6Str_1lyr/Main_log_2025-04-03_02-19-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.6Str_1lyr/Main_log_2025-04-03_12-34-PM.csv')
]

# MAK = [
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.6strg_30sync/MAK_log_2025-04-03_12-30-PM.csv'),
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.6strg_30sync/MAK_log_2025-04-03_12-30-PM.csv')
# ]

MAK = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.6strg_10sync/MAK_log_2025-04-03_04-47-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.6strg_10sync/MAK_log_2025-04-03_04-47-PM.csv')
]

 
SALF_3 = [

    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-03_02-19-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.6Str_3lyr/Main_log_2025-04-03_12-35-PM.csv')
]


average_accuracy_salf_1 = sum(df['Accuracy'] for df in SALF_1) / len(SALF_1)
average_accuracy_mak = sum(df['Accuracy'] for df in MAK) / len(MAK)
average_accuracy_salf_3 = sum(df['Accuracy'] for df in SALF_3) / len(SALF_3)

# average_accuracy_salf_1 = moving_average(average_accuracy_salf_1, window_size=10)
# average_accuracy_mak = moving_average(average_accuracy_mak, window_size=10)
# average_accuracy_salf_3 = moving_average(average_accuracy_salf_3, window_size=10)



plt.plot(average_accuracy_salf_1, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak, label ='MAK')
plt.plot( average_accuracy_salf_3, label ='SALF_UTL_3')
# plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.6' Stragglers with '0.001' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_1)}")
# print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"SALF layer 3 : {max(average_accuracy_salf_3)}")
print(f"MAK  : {max(average_accuracy_mak)}")
# Out:
# SALF layer 1: 33.54
# SALF layer 3 : 28.435000000000002
# MAK  : 33.67

# %%
SALF_1 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.7Str_1lyr/Main_log_2025-04-03_02-18-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.7Str_1lyr/Main_log_2025-04-03_12-35-PM.csv')
]

# MAK = [
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.7strg_30sync/MAK_log_2025-04-03_12-30-PM.csv'),
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.7strg_30sync/MAK_log_2025-04-03_12-31-PM.csv')
# ]


MAK = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.7strg_10sync/MAK_log_2025-04-03_04-47-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.7strg_10sync/MAK_log_2025-04-03_04-47-PM.csv')
]
 
SALF_3 = [

    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-03_02-18-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.7Str_3lyr/Main_log_2025-04-03_12-35-PM.csv')
]

average_accuracy_salf_1 = sum(df['Accuracy'] for df in SALF_1) / len(SALF_1)
average_accuracy_mak = sum(df['Accuracy'] for df in MAK) / len(MAK)
average_accuracy_salf_3 = sum(df['Accuracy'] for df in SALF_3) / len(SALF_3)

plt.plot(average_accuracy_salf_1, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak, label ='MAK')
plt.plot( average_accuracy_salf_3, label ='SALF_UTL_3')
# plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.7' Stragglers with '0.001' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_1)}")
# print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"SALF layer 3 : {max(average_accuracy_salf_3)}")
print(f"MAK  : {max(average_accuracy_mak)}")
# Out:
# SALF layer 1: 32.765
# SALF layer 3 : 28.240000000000002
# MAK  : 34.2

# %%
SALF_1 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.8Str_1lyr/Main_log_2025-04-03_02-05-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.8Str_1lyr/Main_log_2025-04-03_12-35-PM.csv')
]

# MAK = [
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.8strg_30sync/MAK_log_2025-04-03_12-29-PM.csv'),
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.8strg_30sync/MAK_log_2025-04-03_12-31-PM.csv')
# ]

MAK = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.8strg_10sync/MAK_log_2025-04-03_04-47-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.8strg_10sync/MAK_log_2025-04-03_04-47-PM.csv')
]

 
SALF_3 = [

    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.8Str_3lyr/Main_log_2025-04-03_02-30-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.8Str_3lyr/Main_log_2025-04-03_12-36-PM.csv')
]

average_accuracy_salf_1 = sum(df['Accuracy'] for df in SALF_1) / len(SALF_1)
average_accuracy_mak = sum(df['Accuracy'] for df in MAK) / len(MAK)
average_accuracy_salf_3 = sum(df['Accuracy'] for df in SALF_3) / len(SALF_3)

plt.plot(average_accuracy_salf_1, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak, label ='MAK')
plt.plot( average_accuracy_salf_3, label ='SALF_UTL_3')
# plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.8' Stragglers with '0.001' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_1)}")
# print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"SALF layer 3 : {max(average_accuracy_salf_3)}")
print(f"MAK  : {max(average_accuracy_mak)}")
# Out:
# SALF layer 1: 31.299999999999997
# SALF layer 3 : 26.57
# MAK  : 34.905

# %%
SALF_1 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.9Str_1lyr/Main_log_2025-04-03_02-19-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.9Str_1lyr/Main_log_2025-04-03_12-33-PM.csv')
]

# MAK = [
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.9strg_30sync/MAK_log_2025-04-03_12-31-PM.csv'),
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.9strg_30sync/MAK_log_2025-04-03_12-31-PM.csv')
# ]

MAK = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.9strg_10sync/MAK_log_2025-04-03_04-47-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.9strg_10sync/MAK_log_2025-04-03_04-48-PM.csv')
]


 
SALF_3 = [

    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_1234Seed_0.9Str_3lyr/Main_log_2025-04-03_02-19-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.001dir_5555Seed_0.9Str_3lyr/Main_log_2025-04-03_12-33-PM.csv')
]

average_accuracy_salf_1 = sum(df['Accuracy'] for df in SALF_1) / len(SALF_1)
average_accuracy_mak = sum(df['Accuracy'] for df in MAK) / len(MAK)
average_accuracy_salf_3 = sum(df['Accuracy'] for df in SALF_3) / len(SALF_3)

plt.plot(average_accuracy_salf_1, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak, label ='MAK')
plt.plot( average_accuracy_salf_3, label ='SALF_UTL_3')
# plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.9' Stragglers with '0.001' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_1)}")
# print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"SALF layer 3 : {max(average_accuracy_salf_3)}")
print(f"MAK  : {max(average_accuracy_mak)}")
# Out:
# SALF layer 1: 28.71
# SALF layer 3 : 24.66
# MAK  : 34.455

# %%
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define straggler percentages and non-IID levels
straggler_percentages = [0.6, 0.7, 0.8, 0.9]
non_iid_levels = [0.001, 0.01, 0.05, 0.1]

# Generate dummy performance data (replace with real values if available)
performance_data = np.random.rand(len(non_iid_levels), len(straggler_percentages))

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(performance_data, annot=True, xticklabels=straggler_percentages, yticklabels=non_iid_levels, cmap="coolwarm", cbar=True)

# Labels and title
plt.xlabel("Straggler Percentage")
plt.ylabel("Non-IID Level")
plt.title("Performance Impact of Straggler Percentage and Non-IID Data")

# Show plot
plt.show()

# %% [markdown]
# # 0.05

# %%
SALF_1 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.6Str_1lyr/Main_log_2025-04-03_06-39-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.6Str_1lyr/Main_log_2025-03-28_01-34-PM.csv')
]

# MAK = [
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.9strg_30sync/MAK_log_2025-04-03_12-31-PM.csv'),
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.9strg_30sync/MAK_log_2025-04-03_12-31-PM.csv')
# ]

MAK = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.6strg_10sync/MAK_log_2025-04-03_06-36-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.6strg_10sync/MAK_log_2025-04-03_06-37-PM.csv')
]


 
SALF_3 = [

    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-03_06-39-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.6Str_3lyr/Main_log_2025-04-02_04-03-PM.csv')
]

average_accuracy_salf_1 = sum(df['Accuracy'] for df in SALF_1) / len(SALF_1)
average_accuracy_mak = sum(df['Accuracy'] for df in MAK) / len(MAK)
average_accuracy_salf_3 = sum(df['Accuracy'] for df in SALF_3) / len(SALF_3)

plt.plot(average_accuracy_salf_1, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak, label ='MAK')
plt.plot( average_accuracy_salf_3, label ='SALF_UTL_3')
# plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.6' Stragglers with '0.05' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_1)}")
# print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"SALF layer 3 : {max(average_accuracy_salf_3)}")
print(f"MAK  : {max(average_accuracy_mak)}")

# %%
SALF_1 = [
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.7Str_1lyr/Main_log_2025-04-03_06-39-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_5555Seed_0.7Str_1lyr/Main_log_2025-03-28_05-41-PM.csv')
]

# MAK = [
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_1234Seed_0.9strg_30sync/MAK_log_2025-04-03_12-31-PM.csv'),
#     pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.001dir_5555Seed_0.9strg_30sync/MAK_log_2025-04-03_12-31-PM.csv')
# ]

MAK = [
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_5555Seed_0.7strg_10sync/MAK_log_2025-04-03_06-37-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Make_logs/FIRST_Exception/0.05dir_1234Seed_0.7strg_10sync/MAK_log_2025-04-03_06-37-PM.csv')
]


 
SALF_3 = [

    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-03_06-39-PM.csv'),
    pd.read_csv('/home/wahab/SALF/SALF/Main_logs/0.05dir_1234Seed_0.7Str_3lyr/Main_log_2025-04-02_02-35-PM.csv')
]

average_accuracy_salf_1 = sum(df['Accuracy'] for df in SALF_1) / len(SALF_1)
average_accuracy_mak = sum(df['Accuracy'] for df in MAK) / len(MAK)
average_accuracy_salf_3 = sum(df['Accuracy'] for df in SALF_3) / len(SALF_3)

plt.plot(average_accuracy_salf_1, label = 'SALF_UTL_1')
plt.plot(average_accuracy_mak, label ='MAK')
plt.plot( average_accuracy_salf_3, label ='SALF_UTL_3')
# plt.plot(SALF_01_3['Accuracy'], label = 'SALF_UTL_3')
plt.legend()
plt.grid(True)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title("'0.7' Stragglers with '0.05' Dirichlet")

print(f"SALF layer 1: {max(average_accuracy_salf_1)}")
# print(f"SALF layer 3: {max(SALF_01_3['Accuracy'])}")
print(f"SALF layer 3 : {max(average_accuracy_salf_3)}")
print(f"MAK  : {max(average_accuracy_mak)}")
